# %% [markdown]
# <a href="https://colab.research.google.com/github/SaraElizabethGarciaCajero/Colab/blob/main/ASE_Garc%C3%ADa_Cajero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sara Elizabeth García Cajero
#
# ASE I: El embarazo adolescente y su relación con diversos problemas sociales

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import files #Sirve para cargar archivos desde el disco duro a google colab
uploaded = files.upload()
# Out:
#      <input type="file" id="files-34940a11-92fc-44c2-88e7-0a5adfc55b6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34940a11-92fc-44c2-88e7-0a5adfc55b6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datos = pd.read_csv("Natalidad_02.csv", sep=';')#Lee el archivo que anteriormente ya fue cargado

# %%
datos.head()
# Out:
#   Instituto Nacional de Estadística y Geografía (INEGI)  Unnamed: 1  \
# 0  Porcentaje de nacimientos registrados de madre...            NaN
# 1                                                NaN            NaN
# 2  Entidad federativa de residencia habitual de l...         2010.0
# 3                           Estados Unidos Mexicanos           18.8
# 4                                     Aguascalientes           18.4
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2      2011.0      2012.0      2013.0      2014.0      2015.0      2016.0
# 3        19.2        19.4        19.4        19.2        18.2        17.8
# 4        18.9        18.9        18.8        19.8        17.8        17.3
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# ...

# %%
datos.drop(datos.index[36:48], inplace=True)
datos
# Out:
#    Instituto Nacional de Estadística y Geografía (INEGI)  Unnamed: 1  \
# 2   Entidad federativa de residencia habitual de l...         2010.0
# 3                            Estados Unidos Mexicanos           18.8
# 4                                      Aguascalientes           18.4
# 5                                     Baja California           20.3
# 6                                 Baja California Sur           19.7
# 7                                            Campeche           20.2
# 8                                Coahuila de Zaragoza           21.8
# 9                                              Colima           19.6
# 10                                            Chiapas           18.8
# 11                                          Chihuahua           23.0
# 12                                   Ciudad de México           16.5
# 13                                            Durango           21.4
# 14                                         Guanajuato           17.6
# ...

# %%
datos.drop([36,37], axis=0, inplace=True)
datos
# Out:
#    Instituto Nacional de Estadística y Geografía (INEGI)  Unnamed: 1  \
# 2   Entidad federativa de residencia habitual de l...         2010.0
# 3                            Estados Unidos Mexicanos           18.8
# 4                                      Aguascalientes           18.4
# 5                                     Baja California           20.3
# 6                                 Baja California Sur           19.7
# 7                                            Campeche           20.2
# 8                                Coahuila de Zaragoza           21.8
# 9                                              Colima           19.6
# 10                                            Chiapas           18.8
# 11                                          Chihuahua           23.0
# 12                                   Ciudad de México           16.5
# 13                                            Durango           21.4
# 14                                         Guanajuato           17.6
# ...

# %%
datos.max()
# Out:
# Instituto Nacional de Estadística y Geografía (INEGI)    Zacatecas
# Unnamed: 1                                                  2010.0
# Unnamed: 2                                                  2011.0
# Unnamed: 3                                                  2012.0
# Unnamed: 4                                                  2013.0
# Unnamed: 5                                                  2014.0
# Unnamed: 6                                                  2015.0
# Unnamed: 7                                                  2016.0
# Unnamed: 8                                                  2017.0
# Unnamed: 9                                                  2018.0
# Unnamed: 10                                                 2019.0
# Unnamed: 11                                                 2020.0
# Unnamed: 12                                                 2021.0
# dtype: object
